# %% [markdown]
# # Chapter 11

# %% [markdown]
# #### Neural Network Example Code
# #### I Try to change the Optimizer from "Adam" to "SGD" the accuracy become lower, from 0.98 to 0.96
# #### I also Try to change the Optimizer from "Adam" to "Adadelta" the accuracy same is 0.98
# #### When i try change the activation from "relu" to "sigmoid" the accuracy become lower to 0.97 so i will change it again
# #### i try the activation with "tanh" the result is same around 0.97
# #### when i try the activation with "softmax" it become worst, so the best activation is "relu" for this cases

# %%
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Size of image is 28x28x1 channel.
input_shape = (28, 28, 1)
batch_size = 64
# number of possible outcomes [0-9]
nclasses = 10
epochs = 3

# Fetch the train and test data.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the image so that all pixel values
# are between -0.5 and +0.5.
x_train = (x_train / 255) - 0.5
x_test = (x_test / 255) - 0.5

# Reshape the train and test images to size 28x28x1.
x_train = x_train.reshape((x_train.shape[0], *input_shape))
x_test = x_test.reshape((x_test.shape[0], *input_shape))

# Define the CNN model with 2 convolution layer and
# 2 max pooling layer followed by a neural network
# with 1 hidden layer of size 128 nodes.
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(nclasses, activation='softmax'))

# Compile the model using Adam optimizer and use
# the cross entropy loss.
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model.
model.fit(x_train, to_categorical(y_train), epochs=epochs,
          batch_size=batch_size)

# Evaluate the model.
score = model.evaluate(x_test, to_categorical(y_test), verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
#plt.imshow()
plt.show()
# Out:
# Epoch 1/3
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.1750 - accuracy: 0.9461
# Epoch 2/3
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.0492 - accuracy: 0.9851
# Epoch 3/3
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0333 - accuracy: 0.9892
# Test loss: 0.03377570832953206
# Test accuracy: 0.9890999794006348

# %%
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Size of image is 28x28x1 channel.
input_shape = (28, 28, 1)
batch_size = 64
# number of possible outcomes [0-9]
nclasses = 10
epochs = 3

# Fetch the train and test data.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the image so that all pixel values
# are between -0.5 and +0.5.
x_train = (x_train / 255) - 0.5
x_test = (x_test / 255) - 0.5

# Reshape the train and test images to size 28x28x1.
x_train = x_train.reshape((x_train.shape[0], *input_shape))
x_test = x_test.reshape((x_test.shape[0], *input_shape))

# Define the CNN model with 2 convolution layer and
# 2 max pooling layer followed by a neural network
# with 1 hidden layer of size 128 nodes.
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(nclasses, activation='softmax'))

# Compile the model using Adam optimizer and use
# the cross entropy loss.
model.compile(optimizer='SGD', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model.
model.fit(x_train, to_categorical(y_train), epochs=epochs,
          batch_size=batch_size)

# Evaluate the model.
score = model.evaluate(x_test, to_categorical(y_test), verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
#plt.imshow()
plt.show()
# Out:
# Epoch 1/3
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.9732 - accuracy: 0.7434
# Epoch 2/3
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2369 - accuracy: 0.9294
# Epoch 3/3
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1615 - accuracy: 0.9516
# Test loss: 0.12556740492656826
# Test accuracy: 0.9635000228881836

# %%
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Size of image is 28x28x1 channel.
input_shape = (28, 28, 1)
batch_size = 64
# number of possible outcomes [0-9]
nclasses = 10
epochs = 3

# Fetch the train and test data.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the image so that all pixel values
# are between -0.5 and +0.5.
x_train = (x_train / 255) - 0.5
x_test = (x_test / 255) - 0.5

# Reshape the train and test images to size 28x28x1.
x_train = x_train.reshape((x_train.shape[0], *input_shape))
x_test = x_test.reshape((x_test.shape[0], *input_shape))

# Define the CNN model with 2 convolution layer and
# 2 max pooling layer followed by a neural network
# with 1 hidden layer of size 128 nodes.
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(nclasses, activation='softmax'))

# Compile the model using Adam optimizer and use
# the cross entropy loss.
model.compile(optimizer='Adadelta', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model.
model.fit(x_train, to_categorical(y_train), epochs=epochs,
          batch_size=batch_size)

# Evaluate the model.
score = model.evaluate(x_test, to_categorical(y_test), verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
#plt.imshow()
plt.show()
# Out:
# Epoch 1/3
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1538 - accuracy: 0.9527
# Epoch 2/3
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0449 - accuracy: 0.9860
# Epoch 3/3
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.0312 - accuracy: 0.9905
# Test loss: 0.03191506103408756
# Test accuracy: 0.9887999892234802

# %%
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Size of image is 28x28x1 channel.
input_shape = (28, 28, 1)
batch_size = 64
# number of possible outcomes [0-9]
nclasses = 10
epochs = 3

# Fetch the train and test data.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the image so that all pixel values
# are between -0.5 and +0.5.
x_train = (x_train / 255) - 0.5
x_test = (x_test / 255) - 0.5

# Reshape the train and test images to size 28x28x1.
x_train = x_train.reshape((x_train.shape[0], *input_shape))
x_test = x_test.reshape((x_test.shape[0], *input_shape))

# Define the CNN model with 2 convolution layer and
# 2 max pooling layer followed by a neural network
# with 1 hidden layer of size 128 nodes.
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='sigmoid',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(nclasses, activation='softmax'))

# Compile the model using Adam optimizer and use
# the cross entropy loss.
model.compile(optimizer='Adadelta', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model.
model.fit(x_train, to_categorical(y_train), epochs=epochs,
          batch_size=batch_size)

# Evaluate the model.
score = model.evaluate(x_test, to_categorical(y_test), verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
#plt.imshow()
plt.show()
# Out:
# Epoch 1/3
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.9450 - accuracy: 0.6769
# Epoch 2/3
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.1675 - accuracy: 0.9505
# Epoch 3/3
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.1044 - accuracy: 0.9680
# Test loss: 0.08652394788004458
# Test accuracy: 0.9746000170707703

# %%
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Size of image is 28x28x1 channel.
input_shape = (28, 28, 1)
batch_size = 64
# number of possible outcomes [0-9]
nclasses = 10
epochs = 3

# Fetch the train and test data.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the image so that all pixel values
# are between -0.5 and +0.5.
x_train = (x_train / 255) - 0.5
x_test = (x_test / 255) - 0.5

# Reshape the train and test images to size 28x28x1.
x_train = x_train.reshape((x_train.shape[0], *input_shape))
x_test = x_test.reshape((x_test.shape[0], *input_shape))

# Define the CNN model with 2 convolution layer and
# 2 max pooling layer followed by a neural network
# with 1 hidden layer of size 128 nodes.
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='sigmoid',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(nclasses, activation='softmax'))

# Compile the model using Adam optimizer and use
# the cross entropy loss.
model.compile(optimizer='Adadelta', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model.
model.fit(x_train, to_categorical(y_train), epochs=epochs,
          batch_size=batch_size)

# Evaluate the model.
score = model.evaluate(x_test, to_categorical(y_test), verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
#plt.imshow()
plt.show()
# Out:
# Epoch 1/3
# 60000/60000 [==============================] - 5s 91us/step - loss: 1.0160 - accuracy: 0.6453
# Epoch 2/3
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.1628 - accuracy: 0.9525
# Epoch 3/3
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0993 - accuracy: 0.9700
# Test loss: 0.08747542140781879
# Test accuracy: 0.9708999991416931

# %%
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Size of image is 28x28x1 channel.
input_shape = (28, 28, 1)
batch_size = 64
# number of possible outcomes [0-9]
nclasses = 10
epochs = 3

# Fetch the train and test data.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the image so that all pixel values
# are between -0.5 and +0.5.
x_train = (x_train / 255) - 0.5
x_test = (x_test / 255) - 0.5

# Reshape the train and test images to size 28x28x1.
x_train = x_train.reshape((x_train.shape[0], *input_shape))
x_test = x_test.reshape((x_test.shape[0], *input_shape))

# Define the CNN model with 2 convolution layer and
# 2 max pooling layer followed by a neural network
# with 1 hidden layer of size 128 nodes.
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='softmax',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='softmax'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='softmax'))
model.add(Dense(nclasses, activation='softmax'))

# Compile the model using Adam optimizer and use
# the cross entropy loss.
model.compile(optimizer='Adadelta', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model.
model.fit(x_train, to_categorical(y_train), epochs=epochs,
          batch_size=batch_size)

# Evaluate the model.
score = model.evaluate(x_test, to_categorical(y_test), verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
#plt.imshow()
plt.show()
# Out:
# Epoch 1/3
# 60000/60000 [==============================] - 9s 158us/step - loss: 2.3016 - accuracy: 0.1119
# Epoch 2/3
# 60000/60000 [==============================] - 9s 154us/step - loss: 2.3014 - accuracy: 0.1124
# Epoch 3/3
# 60000/60000 [==============================] - 9s 154us/step - loss: 2.3013 - accuracy: 0.1123
# Test loss: 2.3009456752777098
# Test accuracy: 0.11349999904632568
