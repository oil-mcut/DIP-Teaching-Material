# %% [markdown]
# # Chapter9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 1.9MB 4.3MB/s
# ...

# %%
# %matplotlib inline
import skimage
print(skimage.__version__)

import numpy as np
import PIL as pil

from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract, multiply, difference, screen
import PIL.ImageStat as stat

from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import invert, random_noise, montage

from skimage import viewer
from skimage.viewer import ImageViewer
# https://scikit-image.org/docs/dev/user_guide/viewer.html

import skimage as skim
import skimage.io as skim_io
import skimage.transform as skim_tr
import skimage.util as skim_ut

import matplotlib.image as mpimg
import matplotlib.pylab as plt

from scipy.ndimage import affine_transform, zoom
from scipy import misc
import scipy.ndimage
import scipy
# Out:
# 0.16.2
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Viewer requires Qt
#   del sys.path[0]

# %%
# !pip install scipy
# !pip install "scipy==1.1.0"

# %% [markdown]
# #### Dilation

# %%
from PIL import Image
import scipy.ndimage as snd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Opening the image and converting it to grayscale.
a = Image.open('/content/drive/MyDrive/DIP colab/dil_image.png').convert('L')
a = np.array(a)
# Performing binary dilation for 5 iterations.
b = snd.morphology.binary_dilation(a, iterations=5)
c = snd.morphology.binary_dilation(a, iterations=10)
d = snd.morphology.binary_dilation(a, iterations=20)
# Saving the image as 8-bit as b is a
# binary image of dtype=bool
# img= Image.open('./test/test2.bmp')
# plt.imshow(a,cmap='gray',vmin=0,vmax=255)
# cv2.imshow("oke", b)
# cv2.waitKey(0)
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(2, 2, 1)
imgplot = plt.imshow(a, cmap='gray',vmin=0,vmax=255)
ax.set_title('Before')
ax = fig.add_subplot(2, 2, 2)
imgplot = plt.imshow(b, cmap='gray')
ax.set_title('After_5')
ax = fig.add_subplot(2, 2, 3)
imgplot = plt.imshow(c, cmap='gray')
ax.set_title('After_10')
ax = fig.add_subplot(2, 2, 4)
imgplot = plt.imshow(d, cmap='gray')
ax.set_title('After_20')

plt.show()

# %% [markdown]
# #### Erosion

# %%
from PIL import Image
import scipy.ndimage as snd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Opening the image and converting it to grayscale.
a = Image.open('/content/drive/MyDrive/DIP colab/er_image.png').convert('L')
a = np.array(a)
# Performing binary erosion for 20 iterations.
b = snd.morphology.binary_erosion(a,iterations=20)
c = snd.morphology.binary_erosion(a,iterations=40)
d = snd.morphology.binary_erosion(a,iterations=80)
# Saving the image as 8-bit as b is a
# binary image of dtype=bool
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(2, 2, 1)
imgplot = plt.imshow(a, cmap='gray')
ax.set_title('Before')
ax = fig.add_subplot(2, 2, 2)
imgplot = plt.imshow(b, cmap='gray')
ax.set_title('After_20')
ax = fig.add_subplot(2, 2, 3)
imgplot = plt.imshow(c, cmap='gray')
ax.set_title('After_40')
ax = fig.add_subplot(2, 2, 4)
imgplot = plt.imshow(d, cmap='gray')
ax.set_title('After_80')
plt.show()

# %% [markdown]
# #### Grayscale Dilation and Erosion

# %%
import numpy as np
from PIL import Image
import scipy.ndimage
import matplotlib.pyplot as plt

# Opening the image and converting it into grayscale.
a = Image.open('/content/drive/MyDrive/DIP colab/sem3.png').convert('L')
# Creating a structuring element.
footprint = np.ones((15,15))
footprint1 = np.ones((30,30))
footprint2 = np.ones((60,60))

# Performing grey dilation.
b = scipy.ndimage.morphology.grey_dilation(a, footprint=footprint)
c = scipy.ndimage.morphology.grey_dilation(a, footprint=footprint1)
d = scipy.ndimage.morphology.grey_dilation(a, footprint=footprint2)

# Converting ndarray to image.
c = Image.fromarray(b)
# Saving the image.
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(2, 2, 1)
imgplot = plt.imshow(a, cmap='gray')
ax.set_title('Before')
ax = fig.add_subplot(2, 2, 2)
imgplot = plt.imshow(b, cmap='gray')
ax.set_title('After_15_15')
ax = fig.add_subplot(2, 2, 3)
imgplot = plt.imshow(c, cmap='gray')
ax.set_title('After_30_30')
ax = fig.add_subplot(2, 2, 4)
imgplot = plt.imshow(d, cmap='gray')
ax.set_title('After_60_60')
plt.show()

# %% [markdown]
# #### Opening and Closing

# %%
from PIL import Image
import scipy.ndimage as snd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Opening the image and converting it to .
a = Image.open('/content/drive/MyDrive/DIP colab/dil_image.png').convert('L')
a = np.array(a)
# Defining the structuring element.
s = [[0,1,0],[1,1,1], [0,1,0]]
# Performing the binary opening for 5 iterations.
b = snd.morphology.binary_opening(a, structure=s, iterations=5)
c = snd.morphology.binary_opening(a, structure=s, iterations=10)
d = snd.morphology.binary_opening(a, structure=s, iterations=20)

# Saving the image as 8-bit as b is a
# binary image of dtype=bool
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(2, 2, 1)
imgplot = plt.imshow(a, cmap='gray')
ax.set_title('Before')
ax = fig.add_subplot(2, 2, 2)
imgplot = plt.imshow(b, cmap='gray')
ax.set_title('After_5')
ax = fig.add_subplot(2, 2, 3)
imgplot = plt.imshow(c, cmap='gray')
ax.set_title('After_10')
ax = fig.add_subplot(2, 2, 4)
imgplot = plt.imshow(d, cmap='gray')
ax.set_title('After_20')
plt.show()

# %%
from PIL import Image
import scipy.ndimage as snd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Opening the image and converting it to grayscale.
a = Image.open('/content/drive/MyDrive/DIP colab/dil_image.png').convert('L')
a = np.array(a)
# Defining the structuring element.
s = [[0,1,0],[1,1,1], [0,1,0]]
# Performing the binary closing for 5 iterations.
b = snd.morphology.binary_closing(a,structure=s,iterations=2)
c = snd.morphology.binary_closing(a,structure=s,iterations=4)
d = snd.morphology.binary_closing(a,structure=s,iterations=6)
# Saving the image as 8-bit as b is a
# binary image of dtype=bool
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(2, 2, 1)
imgplot = plt.imshow(a, cmap='gray')
ax.set_title('Before')
ax = fig.add_subplot(2, 2, 2)
imgplot = plt.imshow(b, cmap='gray')
ax.set_title('After_2')
ax = fig.add_subplot(2, 2, 3)
imgplot = plt.imshow(c, cmap='gray')
ax.set_title('After_4')
ax = fig.add_subplot(2, 2, 4)
imgplot = plt.imshow(d, cmap='gray')
ax.set_title('After_6')
plt.show()

# %% [markdown]
# #### Grayscale Opening and Closing

# %%
import numpy as np
from PIL import Image
import scipy.ndimage 
import matplotlib.pyplot as plt

# Opening the image and converting it into grayscale.
a = Image.open('/content/drive/MyDrive/DIP colab/adaptive_example1.png').convert('L')
# Creating a structuring element.
footprint = np.ones((20,20))
footprint1 = np.ones((40,40))
footprint2 = np.ones((60,60))
# Performing grey opening.
b = scipy.ndimage.morphology.grey_opening(a, footprint=footprint)
c1 = scipy.ndimage.morphology.grey_opening(a, footprint=footprint1)
d = scipy.ndimage.morphology.grey_opening(a, footprint=footprint2)
# Converting ndarray to image.
c = Image.fromarray(b)
# Saving the image.
c.save('/content/drive/MyDrive/DIP colab/OUTPUT/grey_opening_output_40.png') 
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(2, 2, 1)
imgplot = plt.imshow(a, cmap='gray')
ax.set_title('Before')
ax = fig.add_subplot(2, 2, 2)
imgplot = plt.imshow(b, cmap='gray')
ax.set_title('After_20_20')
ax = fig.add_subplot(2, 2, 3)
imgplot = plt.imshow(c1, cmap='gray')
ax.set_title('After_40_40')
ax = fig.add_subplot(2, 2, 4)
imgplot = plt.imshow(d, cmap='gray')
ax.set_title('After_60_60')
plt.show()

# %% [markdown]
# ##### The Python code for grayscale closing is given below.

# %%
import numpy as np
from PIL import Image
import scipy.ndimage 
import matplotlib.pyplot as plt

# Opening the image and converting it into grayscale.
a = Image.open('/content/drive/MyDrive/DIP colab/adaptive_example1.png').convert('L')
a = np.asarray(a)
# Creating a structuring element.
fp = np.ones((40,40))
# Performing grey closing.
bg = scipy.ndimage.morphology.grey_closing(a, footprint=fp)
# bg represents the background. 
# We will subtract bg from a to remove the background in a.
bg_free = (a.astype(np.float64) - bg.astype(np.float64))
# We rescale bg_free to 0 to 255.
denom = (bg_free.max()-bg_free.min())
bg_free_norm = (bg_free - bg_free.min())*255/denom
# Converting bg_free_norm to uint8.
bg_free_norm = bg_free_norm.astype(np.uint8)
# Converting bg_free_norm and bg to images.
bg_free_norm = Image.fromarray(bg_free_norm)
bg = Image.fromarray(bg)
# Saving the background image.
bg.save('/content/drive/MyDrive/DIP colab/OUTPUT/grey_closing_out_40.png')  
# Saving the bg_free_norm image.
bg_free_norm.save('/content/drive/MyDrive/DIP colab/OUTPUT/closing_bgfree.png') 
fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(a, cmap='gray')
ax.set_title('Before')
ax = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow(b, cmap='gray')
ax.set_title('After')
plt.show()

# %% [markdown]
# #### Hit-or-Miss

# %%
from PIL import Image
import numpy as np
import scipy.ndimage as snd
import cv2
import matplotlib.pyplot as plt

# Opening the image and converting it to grayscale.
a = Image.open('/content/drive/MyDrive/DIP colab/thickening_input.png').convert('L')
a = np.array(a)
#print(a)
# Defining the structuring element.
structure1 = np.array([[1, 1, 0], [1, 1, 1],
             [1, 1, 1]])
# Performing the binary hit-or-miss.
b = snd.morphology.binary_hit_or_miss(a, structure1=structure1)

# Saving the image as 8-bit as b is a
# binary image of dtype=bool
# plt.imshow(b)
# plt.show()
#plt.plot(a)
#plt.show()
#plt.subplot(1,2,1)
#plt.plot(b)
#plt.subplot(1,2,2)
# plt.plot(data3)
#plt.show()
fig = plt.figure(figsize=(40, 40))
ax = fig.add_subplot(2, 1, 1)
imgplot = plt.imshow(a, cmap='gray')
ax.set_title('Before')
ax = fig.add_subplot(2, 1, 2)
imgplot = plt.imshow(b, cmap='gray')
plt.savefig("/content/drive/MyDrive/DIP colab/OUTPUT/thickening_output.png") # save the dark image
ax.set_title('After')
plt.show()

# %% [markdown]
# ### Skeletonization

# %%
import numpy as np
from PIL import Image
from skimage.morphology import skeletonize
import cv2
import matplotlib.pyplot as plt

# Opening the image and converting it to grayscale.
a = Image.open('/content/drive/MyDrive/DIP colab/steps1.png').convert('L')
# Converting a to an ndarray and normalizing it.
a = np.asarray(a)/np.max(a)
# Performing skeletonization.
b = skeletonize(a)
# Saving the image as 8-bit as b is a
# binary image of dtype=bool
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(a, cmap='gray')
ax.set_title('Before')
ax = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow(b, cmap='gray')
ax.set_title('After')
plt.show()
